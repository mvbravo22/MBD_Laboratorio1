# %%
#librerias
import sqlalchemy
from sqlalchemy import create_engine
from sqlalchemy import Table, Column, Integer, String, MetaData, ForeignKey
from sqlalchemy import inspect

# %%
#Conectar el motor al archivo de la base de datos a usar
engine = create_engine('sqlite:///chinook.db')
engine
# Out:
# Engine(sqlite:///chinook.db)

# %%
metadata = MetaData() 
metadata.create_all(engine) 
inspector = inspect(engine) 
inspector.get_columns('customers')

#Revisé las columnas en la tabla de Tracks
# Out:
# [{'name': 'CustomerId',
#   'type': INTEGER(),
#   'nullable': False,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 1},
#  {'name': 'FirstName',
#   'type': NVARCHAR(length=40),
#   'nullable': False,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'LastName',
#   'type': NVARCHAR(length=20),
#   'nullable': False,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'Company',
#   'type': NVARCHAR(length=80),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'Address',
#   'type': NVARCHAR(length=70),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'City',
#   'type': NVARCHAR(length=40),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'State',
#   'type': NVARCHAR(length=40),
#   'nullable': True,
#   'default': None,
# ...

# %%
# Transform
#INVOICES
#Crear la consulta que haga el cambio en la tabla invoices cambiando los NULL con NA

with engine.connect() as con:
    
    rs = con.execute("""SELECT InvoiceId,
       InvoiceDate,
       BillingAddress,
       BillingCity,
       CASE
           WHEN BillingState is NOT NULL then BillingState
       ELSE 'NA'
        END
       BillingState,
       BillingCountry,
       CASE
           WHEN BillingPostalCode is NOT NULL then BillingPostalCode
       ELSE 'NA'
       END
       BillingPostalCode,
       Total
  FROM invoices;""")
    
    for row in rs:
        print(row)
        
con.close()
# Out:
# (1, '2009-01-01 00:00:00', 'Theodor-Heuss-Straße 34', 'Stuttgart', 'NA', 'Germany', '70174', 1.98)
# (2, '2009-01-02 00:00:00', 'Ullevålsveien 14', 'Oslo', 'NA', 'Norway', '0171', 3.96)
# (3, '2009-01-03 00:00:00', 'Grétrystraat 63', 'Brussels', 'NA', 'Belgium', '1000', 5.94)
# (4, '2009-01-06 00:00:00', '8210 111 ST NW', 'Edmonton', 'AB', 'Canada', 'T6G 2C7', 8.91)
# (5, '2009-01-11 00:00:00', '69 Salem Street', 'Boston', 'MA', 'USA', '2113', 13.86)
# (6, '2009-01-19 00:00:00', 'Berger Straße 10', 'Frankfurt', 'NA', 'Germany', '60316', 0.99)
# (7, '2009-02-01 00:00:00', 'Barbarossastraße 19', 'Berlin', 'NA', 'Germany', '10779', 1.98)
# (8, '2009-02-01 00:00:00', '8, Rue Hanovre', 'Paris', 'NA', 'France', '75002', 1.98)
# (9, '2009-02-02 00:00:00', '9, Place Louis Barthou', 'Bordeaux', 'NA', 'France', '33000', 3.96)
# (10, '2009-02-03 00:00:00', '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', 'NA', 5.94)
# ...

# %%
# Transform
#CUSTOMERS
#Crear la consulta que haga el cambio en la tabla customers cambiando los NULL con NA

with engine.connect() as con:
    
    rs = con.execute("""SELECT CustomerId,FirstName,LastName,
       CASE
           WHEN Company is NOT NULL then Company
       ELSE 'NA'
       END
       Company,Address,City,
       CASE
           WHEN State is NOT NULL then State
       ELSE 'NA'
        END
       State,Country,
       CASE
           WHEN PostalCode is NOT NULL then PostalCode
       ELSE 'NA'
        END
       PostalCode,
       Phone,
        CASE
           WHEN Fax is NOT NULL then Fax
       ELSE 'NA'
        END
       Fax,Email
      
  FROM customers;""")
    
    for row in rs:
        print(row)
        
con.close()
# Out:
# (1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br')
# (2, 'Leonie', 'Köhler', 'NA', 'Theodor-Heuss-Straße 34', 'Stuttgart', 'NA', 'Germany', '70174', '+49 0711 2842222', 'NA', 'leonekohler@surfeu.de')
# (3, 'François', 'Tremblay', 'NA', '1498 rue Bélanger', 'Montréal', 'QC', 'Canada', 'H2G 1A7', '+1 (514) 721-4711', 'NA', 'ftremblay@gmail.com')
# (4, 'Bjørn', 'Hansen', 'NA', 'Ullevålsveien 14', 'Oslo', 'NA', 'Norway', '0171', '+47 22 44 22 22', 'NA', 'bjorn.hansen@yahoo.no')
# (5, 'František', 'Wichterlová', 'JetBrains s.r.o.', 'Klanova 9/506', 'Prague', 'NA', 'Czech Republic', '14700', '+420 2 4172 5555', '+420 2 4172 5555', 'frantisekw@jetbrains.com')
# (6, 'Helena', 'Holý', 'NA', 'Rilská 3174/6', 'Prague', 'NA', 'Czech Republic', '14300', '+420 2 4177 0449', 'NA', 'hholy@gmail.com')
# ...

# %%
#TABLA INVOICES_ITEMS
with engine.connect() as con:
    
    rs = con.execute('SELECT InvoiceLineId,UnitPrice,Quantity FROM invoice_items;')
    
    for row in rs:
        print(row)
        
con.close()
# Out:
# (1, 0.99, 1)
# (2, 0.99, 1)
# (3, 0.99, 1)
# (4, 0.99, 1)
# (5, 0.99, 1)
# (6, 0.99, 1)
# (7, 0.99, 1)
# (8, 0.99, 1)
# (9, 0.99, 1)
# (10, 0.99, 1)
# (11, 0.99, 1)
# (12, 0.99, 1)
# (13, 0.99, 1)
# (14, 0.99, 1)
# (15, 0.99, 1)
# (16, 0.99, 1)
# (17, 0.99, 1)
# (18, 0.99, 1)
# (19, 0.99, 1)
# (20, 0.99, 1)
# (21, 0.99, 1)
# (22, 0.99, 1)
# (23, 0.99, 1)
# (24, 0.99, 1)
# (25, 0.99, 1)
# (26, 0.99, 1)
# (27, 0.99, 1)
# (28, 0.99, 1)
# (29, 0.99, 1)
# (30, 0.99, 1)
# (31, 0.99, 1)
# (32, 0.99, 1)
# (33, 0.99, 1)
# (34, 0.99, 1)
# (35, 0.99, 1)
# (36, 0.99, 1)
# (37, 0.99, 1)
# (38, 0.99, 1)
# (39, 0.99, 1)
# (40, 0.99, 1)
# (41, 0.99, 1)
# (42, 0.99, 1)
# (43, 0.99, 1)
# (44, 0.99, 1)
# (45, 0.99, 1)
# (46, 0.99, 1)
# (47, 0.99, 1)
# (48, 0.99, 1)
# (49, 0.99, 1)
# (50, 0.99, 1)
# (51, 0.99, 1)
# (52, 0.99, 1)
# (53, 0.99, 1)
# (54, 0.99, 1)
# (55, 0.99, 1)
# (56, 0.99, 1)
# (57, 0.99, 1)
# (58, 0.99, 1)
# (59, 0.99, 1)
# (60, 0.99, 1)
# (61, 0.99, 1)
# (62, 0.99, 1)
# (63, 0.99, 1)
# ...

# %%
#TABLA GENERO
with engine.connect() as con:
    
    rs = con.execute('SELECT GenreId,Name FROM genres;')
    
    for row in rs:
        print(row)
        
con.close()
# Out:
# (1, 'Rock')
# (2, 'Jazz')
# (3, 'Metal')
# (4, 'Alternative & Punk')
# (5, 'Rock And Roll')
# (6, 'Blues')
# (7, 'Latin')
# (8, 'Reggae')
# (9, 'Pop')
# (10, 'Soundtrack')
# (11, 'Bossa Nova')
# (12, 'Easy Listening')
# (13, 'Heavy Metal')
# (14, 'R&B/Soul')
# (15, 'Electronica/Dance')
# (16, 'World')
# (17, 'Hip Hop/Rap')
# (18, 'Science Fiction')
# (19, 'TV Shows')
# (20, 'Sci Fi & Fantasy')
# (21, 'Drama')
# (22, 'Comedy')
# (23, 'Alternative')
# (24, 'Classical')
# (25, 'Opera')

# %%
#TABLA ARTISTAS
with engine.connect() as con:
    
    rs = con.execute('SELECT ArtistId, Name FROM artists;')
    
    for row in rs:
        print(row)
        
con.close()
# Out:
# (1, 'AC/DC')
# (2, 'Accept')
# (3, 'Aerosmith')
# (4, 'Alanis Morissette')
# (5, 'Alice In Chains')
# (6, 'Antônio Carlos Jobim')
# (7, 'Apocalyptica')
# (8, 'Audioslave')
# (9, 'BackBeat')
# (10, 'Billy Cobham')
# (11, 'Black Label Society')
# (12, 'Black Sabbath')
# (13, 'Body Count')
# (14, 'Bruce Dickinson')
# (15, 'Buddy Guy')
# (16, 'Caetano Veloso')
# (17, 'Chico Buarque')
# (18, 'Chico Science & Nação Zumbi')
# (19, 'Cidade Negra')
# (20, 'Cláudio Zoli')
# (21, 'Various Artists')
# (22, 'Led Zeppelin')
# (23, 'Frank Zappa & Captain Beefheart')
# (24, 'Marcos Valle')
# (25, 'Milton Nascimento & Bebeto')
# (26, 'Azymuth')
# (27, 'Gilberto Gil')
# (28, 'João Gilberto')
# (29, 'Bebel Gilberto')
# (30, 'Jorge Vercilo')
# (31, 'Baby Consuelo')
# (32, 'Ney Matogrosso')
# (33, 'Luiz Melodia')
# (34, 'Nando Reis')
# (35, 'Pedro Luís & A Parede')
# (36, 'O Rappa')
# (37, 'Ed Motta')
# (38, 'Banda Black Rio')
# (39, 'Fernanda Porto')
# (40, 'Os Cariocas')
# (41, 'Elis Regina')
# ...

# %%
#TABLA ALBUMS
with engine.connect() as con:
    
    rs = con.execute('SELECT AlbumId, Title FROM albums;')
    
    for row in rs:
        print(row)
        
con.close()
# Out:
# (1, 'For Those About To Rock We Salute You')
# (2, 'Balls to the Wall')
# (3, 'Restless and Wild')
# (4, 'Let There Be Rock')
# (5, 'Big Ones')
# (6, 'Jagged Little Pill')
# (7, 'Facelift')
# (8, 'Warner 25 Anos')
# (9, 'Plays Metallica By Four Cellos')
# (10, 'Audioslave')
# (11, 'Out Of Exile')
# (12, 'BackBeat Soundtrack')
# (13, 'The Best Of Billy Cobham')
# (14, 'Alcohol Fueled Brewtality Live! [Disc 1]')
# (15, 'Alcohol Fueled Brewtality Live! [Disc 2]')
# (16, 'Black Sabbath')
# (17, 'Black Sabbath Vol. 4 (Remaster)')
# (18, 'Body Count')
# (19, 'Chemical Wedding')
# (20, 'The Best Of Buddy Guy - The Millenium Collection')
# (21, 'Prenda Minha')
# (22, 'Sozinho Remix Ao Vivo')
# (23, 'Minha Historia')
# (24, 'Afrociberdelia')
# (25, 'Da Lama Ao Caos')
# (26, 'Acústico MTV [Live]')
# (27, 'Cidade Negra - Hits')
# (28, 'Na Pista')
# (29, 'Axé Bahia 2001')
# (30, 'BBC Sessions [Disc 1] [Live]')
# (31, 'Bongo Fury')
# (32, 'Carnaval 2001')
# (33, 'Chill: Brazil (Disc 1)')
# ...

# %%
# Transform
#EMPLOYEES


with engine.connect() as con:
    
    rs = con.execute("""SELECT EmployeeId,
       LastName,
       FirstName,
       Title,
       BirthDate,
       HireDate,
       Address,
       City,
       State,
       Country,
       PostalCode,
       Phone,
       Fax,
       Email
  FROM employees;
""")
    
    for row in rs:
        print(row)
        
con.close()
# Out:
# (1, 'Adams', 'Andrew', 'General Manager', '1962-02-18 00:00:00', '2002-08-14 00:00:00', '11120 Jasper Ave NW', 'Edmonton', 'AB', 'Canada', 'T5K 2N1', '+1 (780) 428-9482', '+1 (780) 428-3457', 'andrew@chinookcorp.com')
# (2, 'Edwards', 'Nancy', 'Sales Manager', '1958-12-08 00:00:00', '2002-05-01 00:00:00', '825 8 Ave SW', 'Calgary', 'AB', 'Canada', 'T2P 2T3', '+1 (403) 262-3443', '+1 (403) 262-3322', 'nancy@chinookcorp.com')
# (3, 'Peacock', 'Jane', 'Sales Support Agent', '1973-08-29 00:00:00', '2002-04-01 00:00:00', '1111 6 Ave SW', 'Calgary', 'AB', 'Canada', 'T2P 5M5', '+1 (403) 262-3443', '+1 (403) 262-6712', 'jane@chinookcorp.com')
# (4, 'Park', 'Margaret', 'Sales Support Agent', '1947-09-19 00:00:00', '2003-05-03 00:00:00', '683 10 Street SW', 'Calgary', 'AB', 'Canada', 'T2P 5G3', '+1 (403) 263-4423', '+1 (403) 263-4289', 'margaret@chinookcorp.com')
# ...

# %%
#TABLA ALBUMS
with engine.connect() as con:
    
    rs = con.execute('SELECT PlaylistId, Name FROM playlists;')
    
    for row in rs:
        print(row)
        
con.close()
# Out:
# (1, 'Music')
# (2, 'Movies')
# (3, 'TV Shows')
# (4, 'Audiobooks')
# (5, '90’s Music')
# (6, 'Audiobooks')
# (7, 'Movies')
# (8, 'Music')
# (9, 'Music Videos')
# (10, 'TV Shows')
# (11, 'Brazilian Music')
# (12, 'Classical')
# (13, 'Classical 101 - Deep Cuts')
# (14, 'Classical 101 - Next Steps')
# (15, 'Classical 101 - The Basics')
# (16, 'Grunge')
# (17, 'Heavy Metal Classic')
# (18, 'On-The-Go 1')

# %%
#Cargar a última query. Aquí debe utilizar un objeto dataframe
# invoices
import pandas as pd
df = pd.read_sql_query("""SELECT InvoiceId,
       InvoiceDate,
       BillingAddress,
       BillingCity,
       CASE
           WHEN BillingState is NOT NULL then BillingState
       ELSE 'NA'
        END
       BillingState,
       BillingCountry,
       CASE
           WHEN BillingPostalCode is NOT NULL then BillingPostalCode
       ELSE 'NA'
       END
       BillingPostalCode,
       Total
  FROM invoices;""", con=engine.connect())

# %%
df.head()
# Out:
#    InvoiceId          InvoiceDate           BillingAddress BillingCity  \
# 0          1  2009-01-01 00:00:00  Theodor-Heuss-Straße 34   Stuttgart
# 1          2  2009-01-02 00:00:00         Ullevålsveien 14        Oslo
# 2          3  2009-01-03 00:00:00          Grétrystraat 63    Brussels
# 3          4  2009-01-06 00:00:00           8210 111 ST NW    Edmonton
# 4          5  2009-01-11 00:00:00          69 Salem Street      Boston
#
#   BillingState BillingCountry BillingPostalCode  Total
# 0           NA        Germany             70174   1.98
# 1           NA         Norway              0171   3.96
# 2           NA        Belgium              1000   5.94
# 3           AB         Canada           T6G 2C7   8.91
# 4           MA            USA              2113  13.86

# %%
#Exportar el archivo en un formato a su elección.

df.to_csv('dataframe_dim_invoices.csv')

# %%
#Cargar a última query. Aquí debe utilizar un objeto dataframe
# customers
import pandas as pd
df1 = pd.read_sql_query("""SELECT CustomerId,FirstName,LastName,
       CASE
           WHEN Company is NOT NULL then Company
       ELSE 'NA'
       END
       Company,Address,City,
       CASE
           WHEN State is NOT NULL then State
       ELSE 'NA'
        END
       State,Country,
       CASE
           WHEN PostalCode is NOT NULL then PostalCode
       ELSE 'NA'
        END
       PostalCode,
       Phone,
        CASE
           WHEN Fax is NOT NULL then Fax
       ELSE 'NA'
        END
       Fax,Email
      
  FROM customers;""", con=engine.connect())

# %%
df1.head()
# Out:
#    CustomerId  FirstName     LastName  \
# 0           1       Luís    Gonçalves
# 1           2     Leonie       Köhler
# 2           3   François     Tremblay
# 3           4      Bjørn       Hansen
# 4           5  František  Wichterlová
#
#                                             Company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                                NA
# 2                                                NA
# 3                                                NA
# 4                                  JetBrains s.r.o.
#
#                            Address                 City State         Country  \
# 0  Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP          Brazil
# 1          Theodor-Heuss-Straße 34            Stuttgart    NA         Germany
# 2                1498 rue Bélanger             Montréal    QC          Canada
# 3                 Ullevålsveien 14                 Oslo    NA          Norway
# ...

# %%
#Exportar el archivo en un formato a su elección.

df1.to_csv('dataframe_dim_customers.csv')

# %%
#Cargar a última query. Aquí debe utilizar un objeto dataframe
# invoice_items
import pandas as pd
df2 = pd.read_sql_query("""SELECT InvoiceLineId,UnitPrice,Quantity FROM invoice_items;""", con=engine.connect())

# %%
df2.head()
# Out:
#    InvoiceLineId  UnitPrice  Quantity
# 0              1       0.99         1
# 1              2       0.99         1
# 2              3       0.99         1
# 3              4       0.99         1
# 4              5       0.99         1

# %%
#Exportar el archivo en un formato a su elección.

df2.to_csv('dataframe_dim_invoice_items.csv')

# %%
#Cargar a última query. Aquí debe utilizar un objeto dataframe
# genres
import pandas as pd
df3 = pd.read_sql_query("""SELECT GenreId,Name FROM genres;""", con=engine.connect())

# %%
df3.head()
# Out:
#    GenreId                Name
# 0        1                Rock
# 1        2                Jazz
# 2        3               Metal
# 3        4  Alternative & Punk
# 4        5       Rock And Roll

# %%
#Exportar el archivo en un formato a su elección.

df3.to_csv('dataframe_dim_genres.csv')

# %%
#Cargar a última query. Aquí debe utilizar un objeto dataframe
# artists
import pandas as pd
df4 = pd.read_sql_query("""SELECT ArtistId, Name FROM artists;""", con=engine.connect())

# %%
df4.head()
# Out:
#    ArtistId               Name
# 0         1              AC/DC
# 1         2             Accept
# 2         3          Aerosmith
# 3         4  Alanis Morissette
# 4         5    Alice In Chains

# %%
#Exportar el archivo en un formato a su elección.

df4.to_csv('dataframe_dim_artists.csv')

# %%
#Cargar a última query. Aquí debe utilizar un objeto dataframe
# albums
import pandas as pd
df5 = pd.read_sql_query("""SELECT AlbumId, Title FROM albums;""", con=engine.connect())

# %%
df5.head()
# Out:
#    AlbumId                                  Title
# 0        1  For Those About To Rock We Salute You
# 1        2                      Balls to the Wall
# 2        3                      Restless and Wild
# 3        4                      Let There Be Rock
# 4        5                               Big Ones

# %%
#Exportar el archivo en un formato a su elección.

df5.to_csv('dataframe_dim_albums.csv')

# %%
#Cargar a última query. Aquí debe utilizar un objeto dataframe
# employees
import pandas as pd
df6 = pd.read_sql_query("""SELECT EmployeeId,
       LastName,
       FirstName,
       Title,
       BirthDate,
       HireDate,
       Address,
       City,
       State,
       Country,
       PostalCode,
       Phone,
       Fax,
       Email
  FROM employees;""", con=engine.connect())

# %%
df6.head()
# Out:
#    EmployeeId LastName FirstName                Title            BirthDate  \
# 0           1    Adams    Andrew      General Manager  1962-02-18 00:00:00
# 1           2  Edwards     Nancy        Sales Manager  1958-12-08 00:00:00
# 2           3  Peacock      Jane  Sales Support Agent  1973-08-29 00:00:00
# 3           4     Park  Margaret  Sales Support Agent  1947-09-19 00:00:00
# 4           5  Johnson     Steve  Sales Support Agent  1965-03-03 00:00:00
#
#               HireDate              Address      City State Country  \
# 0  2002-08-14 00:00:00  11120 Jasper Ave NW  Edmonton    AB  Canada
# 1  2002-05-01 00:00:00         825 8 Ave SW   Calgary    AB  Canada
# 2  2002-04-01 00:00:00        1111 6 Ave SW   Calgary    AB  Canada
# 3  2003-05-03 00:00:00     683 10 Street SW   Calgary    AB  Canada
# 4  2003-10-17 00:00:00         7727B 41 Ave   Calgary    AB  Canada
#
#   PostalCode              Phone                Fax                     Email
# ...

# %%
#Exportar el archivo en un formato a su elección.

df6.to_csv('dataframe_dim_employees.csv')

# %%
#Cargar a última query. Aquí debe utilizar un objeto dataframe
# playlists
import pandas as pd
df7 = pd.read_sql_query("""SELECT PlaylistId, Name FROM playlists;""", con=engine.connect())

# %%
df7.head()
# Out:
#    PlaylistId        Name
# 0           1       Music
# 1           2      Movies
# 2           3    TV Shows
# 3           4  Audiobooks
# 4           5  90’s Music

# %%
#Exportar el archivo en un formato a su elección.

df7.to_csv('dataframe_dim_playlists.csv')
